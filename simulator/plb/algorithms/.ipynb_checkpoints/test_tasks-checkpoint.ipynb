# %%
# shared across tasks
from plb.optimizer.optim import Adam
from plb.engine.taichi_env import TaichiEnv
from plb.config.default_config import get_cfg_defaults, CN

import os
import cv2
import numpy as np
import taichi as ti
ti.init(arch=ti.gpu)
import matplotlib.pyplot as plt
from plb.config import load
from tqdm.notebook import tqdm
# Out:
# [Taichi] Starting on arch=cuda

# %%
task_name = 'ngrip'
env_type = '_fixed'

# gripper_fixed.yml
cfg = load(f"../envs/gripper{env_type}.yml") 
print(cfg)
env = TaichiEnv(cfg, nn=False, loss=False)
env.initialize()
state = env.get_state()

env.set_state(**state)
taichi_env = env
print(env.renderer.camera_pos)
env.renderer.camera_pos[0] = 0.5
env.renderer.camera_pos[1] = 2.5
env.renderer.camera_pos[2] = 0.5
env.renderer.camera_rot = (1.57, 0.0)

env.primitives.primitives[0].set_state(0, [0.3, 0.4, 0.5, 1, 0, 0, 0])
env.primitives.primitives[1].set_state(0, [0.7, 0.4, 0.5, 1, 0, 0, 0])

env.render('plt')

action_dim = taichi_env.primitives.action_dim
# Out:
# ENV:
#   loss:
#     soft_contact: False
#     target_path: envs/assets/Chopsticks3D-v1.npy
#     weight:
#       contact: 1
#       density: 10
#       sdf: 10
#   n_observed_particles: 200
# PRIMITIVES: [{'shape': 'Capsule', 'h': 0.2, 'r': 0.045, 'init_pos': '(0.35, 0.4, 0.5)', 'init_rot': '(1., 0., 0., 0.)', 'color': '(0.8, 0.8, 0.8)', 'friction': 1.0, 'action': {'dim': 6, 'scale': '(0.02, 0.02, 0.02, 0.04, 0.04, 0.04)'}}, {'shape': 'Capsule', 'h': 0.2, 'r': 0.045, 'init_pos': '(0.65, 0.4, 0.5)', 'init_rot': '(1., 0., 0., 0.)', 'color': '(0.8, 0.8, 0.8)', 'friction': 1.0, 'action': {'dim': 6, 'scale': '(0.02, 0.02, 0.02, 0.04, 0.04, 0.04)'}}, {'shape': 'Capsule', 'h': 0.13, 'r': 0.025, 'init_pos': '(0.5, 0.1, 0.5)', 'init_rot': '(1., 0., 0., 0.)', 'color': '(0.2, 0.2, 0.2)', 'friction': 15.0}]
# RENDERER:
#   bake_size: 6
#   camera_pos: (0.5, 1.2, 4.0)
#   camera_pos_1: (0.5, 2.5, 2.2)
#   camera_pos_2: (0.5, 2.5, 2.2)
#   camera_pos_3: (0.5, 2.5, 2.2)
#   camera_pos_4: (0.5, 2.5, 2.2)
#   camera_rot: (0.2, 0)
#   camera_rot_1: (0.8, 0.0)
#   camera_rot_2: (0.8, 0.0)
#   camera_rot_3: (0.8, 0.0)
#   camera_rot_4: (0.8, 0.0)
#   dx: 0.006666666666666667
#   image_res: (512, 512)
#   light_direction: (2.0, 1.0, 0.7)
#   max_num_particles: 1000000
#   max_ray_depth: 2
#   sdf_threshold: 0.20720000000000002
#   spp: 50
#   target_res: (64, 64, 64)
#   use_directional_light: False
#   use_roulette: False
#   voxel_res: (168, 168, 168)
# SHAPES: [{'shape': 'box', 'width': '(0.25, 0.2, 0.25)', 'init_pos': '(0.5, 0.1, 0.5)', 'n_particles': 20000, 'color': '((150<<8)+ (150<<16))'}]
# SIMULATOR:
#   E: 5000.0
#   dim: 3
#   dtype: float64
#   gravity: (0, -5, 0)
#   ground_friction: 100.0
#   max_steps: 1024
#   n_particles: 9000
#   nu: 0.2
#   quality: 1
#   yield_stress: 4000.0
# VARIANTS: [{'ENV': {'loss': {'target_path': 'envs/assets/gripper-v1.npy'}}}]
# Building primitive
# action:
#   dim: 6
#   scale: (0.02, 0.02, 0.02, 0.04, 0.04, 0.04)
# color: (0.8, 0.8, 0.8)
# friction: 1.0
# h: 0.2
# init_pos: (0.35, 0.4, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# r: 0.045
# shape: Capsule
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 6
#   scale: (0.02, 0.02, 0.02, 0.04, 0.04, 0.04)
# color: (0.8, 0.8, 0.8)
# friction: 1.0
# h: 0.2
# init_pos: (0.65, 0.4, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# r: 0.045
# shape: Capsule
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# color: (0.2, 0.2, 0.2)
# friction: 15.0
# h: 0.13
# init_pos: (0.5, 0.1, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# r: 0.025
# shape: Capsule
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# {'width': (0.25, 0.2, 0.25), 'init_pos': (0.5, 0.1, 0.5), 'n_particles': 20000, 'color': 9868800}
# Initialize Renderer
# bake_size: 6
# camera_pos: (0.5, 1.2, 4.0)
# camera_pos_1: (0.5, 2.5, 2.2)
# camera_pos_2: (0.5, 2.5, 2.2)
# camera_pos_3: (0.5, 2.5, 2.2)
# camera_pos_4: (0.5, 2.5, 2.2)
# camera_rot: (0.2, 0)
# camera_rot_1: (0.8, 0.0)
# camera_rot_2: (0.8, 0.0)
# camera_rot_3: (0.8, 0.0)
# camera_rot_4: (0.8, 0.0)
# dx: 0.006666666666666667
# image_res: (512, 512)
# light_direction: (2.0, 1.0, 0.7)
# max_num_particles: 1000000
# max_ray_depth: 2
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# use_directional_light: False
# use_roulette: False
# voxel_res: (168, 168, 168)
# [Taichi] materializing...
# [0.5 1.2 4. ]
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$113474] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$113476] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$113478] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$113505] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$113515] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$113868] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$113870] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$113872] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$113899] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$113909] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$114312] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$114314] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$114316] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$114343] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$114353] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$114936] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$114938] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@100] [$114940] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$114967] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@70] [$114977] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.140] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123111] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123113] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123115] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$123142] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$123152] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123505] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123507] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123509] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$123536] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$123546] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123949] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123951] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$123953] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$123980] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$123990] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$124573] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$124575] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@100] [$124577] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$124604] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@70] [$124614] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:19:09.141] [type_check.cpp:visit@71]

# %%
cwd = os.getcwd()
root_dir = cwd + "/../.."
print(f'root: {root_dir}')

task_params = {
    "mid_point": np.array([0.5, 0.14, 0.5, 0, 0, 0]),
    "sample_radius": 0.4,
    "len_per_grip": 30,
    "len_per_grip_back": 10,
    "floor_pos": np.array([0.5, 0, 0.5]),
    "n_shapes": 3, 
    "n_shapes_floor": 9,
    "n_shapes_per_gripper": 11,
    "gripper_mid_pt": int((11 - 1) / 2),
    "gripper_rate_limits": np.array([0.14, 0.06]), # ((0.4 * 2 - (0.23)) / (2 * 30), (0.4 * 2 - 0.15) / (2 * 30)),
    "p_noise_scale": 0.01,
}

if env_type == '':
    task_params["p_noise_scale"] = 0.03

print(f'p_noise_scale: {task_params["p_noise_scale"]}')
# Out:
# root: /home/seohy/colcon_ws/src/RoboCraft/simulator/plb/algorithms/../..
# p_noise_scale: 0.01

# %%
def set_parameters(env: TaichiEnv, yield_stress, E, nu):
    env.simulator.yield_stress.fill(yield_stress)
    _mu, _lam = E / (2 * (1 + nu)), E * nu / ((1 + nu) * (1 - 2 * nu))  # Lame parameters
    env.simulator.mu.fill(_mu)
    env.simulator.lam.fill(_lam)


def update_camera(env):
    env.renderer.camera_pos[0] = 0.5
    env.renderer.camera_pos[1] = 2.5
    env.renderer.camera_pos[2] = 0.5
    env.renderer.camera_rot = (1.57, 0.0)
    env.render_cfg.defrost()
    env.render_cfg.camera_pos_1 = (0.5, 2.5, 2.2)
    env.render_cfg.camera_rot_1 = (0.8, 0.)
    env.render_cfg.camera_pos_2 = (2.4, 2.5, 0.2)
    env.render_cfg.camera_rot_2 = (0.8, 1.8)
    env.render_cfg.camera_pos_3 = (-1.9, 2.5, 0.2)
    env.render_cfg.camera_rot_3 = (0.8, -1.8)
    env.render_cfg.camera_pos_4 = (0.5, 2.5, -1.8)
    env.render_cfg.camera_rot_4 = (0.8, 3.14)


def update_primitive(env, prim1_list, prim2_list):
    env.primitives.primitives[0].set_state(0, prim1_list)
    env.primitives.primitives[1].set_state(0, prim2_list)


def save_files(env, rollout_dir, i):
    files = glob.glob(f"{root_dir}/dataset/{task_name}/{i:03d}/*")
    for f in files:
        os.remove(f)
        
    os.makedirs(f"{rollout_dir}/{i:03d}", exist_ok=True)
    with open(f"{rollout_dir}/{i:03d}"+"/cam_params.npy", 'wb') as f:
        ext1=env.renderer.get_ext(env.render_cfg.camera_rot_1, np.array(env.render_cfg.camera_pos_1))
        ext2=env.renderer.get_ext(env.render_cfg.camera_rot_2, np.array(env.render_cfg.camera_pos_2))
        ext3=env.renderer.get_ext(env.render_cfg.camera_rot_3, np.array(env.render_cfg.camera_pos_3))
        ext4=env.renderer.get_ext(env.render_cfg.camera_rot_4, np.array(env.render_cfg.camera_pos_4))
        intrinsic = env.renderer.get_int()
        cam_params = {'cam1_ext': ext1, 'cam2_ext': ext2, 'cam3_ext': ext3, 'cam4_ext': ext4, 'intrinsic': intrinsic}
        np.save(f, cam_params)


from transforms3d.quaternions import mat2quat
from transforms3d.axangles import axangle2mat
def random_rotate(mid_point, gripper1_pos, gripper2_pos, z_vec):
    mid_point = mid_point[:3]
    z_angle = np.random.uniform(0, np.pi)
    z_mat = axangle2mat(z_vec, z_angle, is_normalized=True)
    all_mat = z_mat
    quat = mat2quat(all_mat)
    return gripper1_pos, gripper2_pos, quat


def random_pose(task_name):
    p_noise_x = task_params["p_noise_scale"] * (np.random.randn() * 2 - 1)
    p_noise_z = task_params["p_noise_scale"] * (np.random.randn() * 2 - 1)
    if task_name == 'ngrip' or task_name == 'ngrip_3d':
        p_noise = np.clip(np.array([p_noise_x, 0, p_noise_z]), a_min=-0.1, a_max=0.1)
    else:
        raise NotImplementedError
    
    new_mid_point = task_params["mid_point"][:3] + p_noise

    rot_noise = np.random.uniform(0, np.pi)

    x1 = new_mid_point[0] - task_params["sample_radius"] * np.cos(rot_noise)
    z1 = new_mid_point[2] + task_params["sample_radius"] * np.sin(rot_noise)
    x2 = new_mid_point[0] + task_params["sample_radius"] * np.cos(rot_noise)
    z2 = new_mid_point[2] - task_params["sample_radius"] * np.sin(rot_noise)
    y = new_mid_point[1]
    z_vec = np.array([np.cos(rot_noise), 0, np.sin(rot_noise)])
    if task_name == 'ngrip':
        gripper1_pos = np.array([x1, y, z1])
        gripper2_pos = np.array([x2, y, z2])
        quat = np.array([1, 0, 0, 0])
    elif task_name == 'ngrip_3d':
        gripper1_pos, gripper2_pos, quat = random_rotate(new_mid_point, np.array([x1, y, z1]), np.array([x2, y, z2]), z_vec)
    else:
        raise NotImplementedError
    return np.concatenate([gripper1_pos, quat]), np.concatenate([gripper2_pos, quat]), rot_noise


def get_obs(env, n_particles, t=0):
    x = env.simulator.get_x(t)
    v = env.simulator.get_v(t)
    step_size = len(x) // n_particles
    return x[::step_size], v[::step_size]


def select_tool(env, width):
    env.primitives.primitives[0].r[None] = width
    env.primitives.primitives[1].r[None] = width

# %%
import glob
from datetime import datetime
from tqdm.notebook import tqdm

i = 0
n_vid = 1
suffix = ''
n_grips = 1
zero_pad = np.array([0,0,0])

time_now = datetime.now().strftime("%d-%b-%Y-%H:%M:%S.%f")
rollout_dir = f"{root_dir}/dataset/{task_name}{env_type}{suffix}_{time_now}"

while i < n_vid: 
    print(f"+++++++++++++++++++{i}+++++++++++++++++++++")
    env.set_state(**state)
    taichi_env = env    
    update_camera(env)
    set_parameters(env, yield_stress=200, E=5e3, nu=0.2) # 200， 5e3, 0.2 # 300, 800, 0.2
    update_primitive(env, [0.3, 0.4, 0.5, 1, 0, 0, 0], [0.7, 0.4, 0.5, 1, 0, 0, 0])
    save_files(env, rollout_dir, i)
    action_dim = env.primitives.action_dim
    imgs = [] 
    true_idx = 0
    for k in range(n_grips):
        print(k)
        prim1, prim2, cur_angle = random_pose(task_name)
        update_primitive(env, prim1, prim2)
        if 'small' in suffix:
            tool_size = 0.025
        else:
            tool_size = 0.045
        select_tool(env, tool_size)
        
        gripper_rate_limit = [(task_params['sample_radius'] * 2 - (task_params['gripper_rate_limits'][0] + 2 * tool_size)) / (2 * task_params['len_per_grip']),
                              (task_params['sample_radius'] * 2 - (task_params['gripper_rate_limits'][1] + 2 * tool_size)) / (2 * task_params['len_per_grip'])]
        rate = np.random.uniform(*gripper_rate_limit)
        actions = []
        counter = 0 
        mid_point = (prim1[:3] + prim2[:3]) / 2
        prim1_direction = mid_point - prim1[:3]
        prim1_direction = prim1_direction / np.linalg.norm(prim1_direction)
        while counter < task_params["len_per_grip"]:
            prim1_action = rate * prim1_direction
            actions.append(np.concatenate([prim1_action/0.02, zero_pad, -prim1_action/0.02, zero_pad]))
            counter += 1
        counter = 0
        while counter < task_params["len_per_grip_back"]:
            prim1_action = -rate * prim1_direction
            actions.append(np.concatenate([prim1_action/0.02, zero_pad, -prim1_action/0.02, zero_pad]))
            counter += 1

        actions = np.stack(actions)
            
        for idx, act in enumerate(tqdm(actions, total=actions.shape[0])):
            env.step(act)
            obs = get_obs(env, 300)
            x = obs[0][:300]
            
            primitive_state = [env.primitives.primitives[0].get_state(0), env.primitives.primitives[1].get_state(0)]

            img = env.render_multi(mode='rgb_array', spp=3)
            rgb, depth = img[0], img[1]

            os.system('mkdir -p ' + f"{rollout_dir}/{i:03d}")
            
            for num_cam in range(4):
                cv2.imwrite(f"{rollout_dir}/{i:03d}/{true_idx:03d}_rgb_{num_cam}.png", rgb[num_cam][..., ::-1])
            with open(f"{rollout_dir}/{i:03d}/{true_idx:03d}_depth_prim.npy", 'wb') as f:
                np.save(f, depth + primitive_state + [tool_size])
            with open(f"{rollout_dir}/{i:03d}/{true_idx:03d}_gtp.npy", 'wb') as f:
                np.save(f, x)
            true_idx += 1

        print(true_idx)
    
    os.system(f'ffmpeg -y -i {rollout_dir}/{i:03d}/%03d_rgb_0.png -c:v libx264 -vf fps=25 -pix_fmt yuv420p {rollout_dir}/{i:03d}/vid{i:03d}.mp4')
    i += 1
# Out:
# +++++++++++++++++++0+++++++++++++++++++++
# 0
#   0%|          | 0/40 [00:00<?, ?it/s]
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151378] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151380] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151382] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151384] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151386] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151388] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151390] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151392] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@100] [$151394] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:16.511] [type_check.cpp:visit@101]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$176516] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$176518] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$176520] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$176547] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$176557] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$176928] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$176930] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$176932] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$176959] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$176969] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$178271] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$178273] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$178275] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$178302] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$178312] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$178683] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$178685] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$178687] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$178714] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$178724] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$180026] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$180028] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$180030] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$180057] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$180067] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$180438] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$180440] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@100] [$180442] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$180469] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@70] [$180479] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:20.103] [type_check.cpp:visit@71]
# [W 09/12/26 14:20:24.618] [type_check.cpp:visit@100] [$209300] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:24.618] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 455, in render_multi
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:24.618] [type_check.cpp:visit@100] [$209302] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:24.618] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 455, in render_multi
#     contrib = self.trace(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# ...
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 456, in render_multi
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@100] [$219779] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 456, in render_multi
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@70] [$219806] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@70] [$219816] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@100] [$220399] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 456, in render_multi
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@100] [$220401] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 456, in render_multi
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@100] [$220403] Local store may lose precision (target = f32, value = f64) at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@101]
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 456, in render_multi
#     depth = self.next_hit(pos, d)[0]
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@70] [$220430] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@71]
#
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@70] [$220440] Atomic add (f64 to f32) may lose precision, at
# [W 09/12/26 14:20:24.619] [type_check.cpp:visit@71]
# /home/seohy/miniconda3/envs/robocraft/lib/python3.8/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
# 40
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/home/seohy/miniconda3/envs/robocraft --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_12-Sep-2026-14:20:15.791672/000/%03d_rgb_0.png':
#   Duration: 00:00:01.60, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x617188c13a80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x617188c13a80] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x617188c13a80] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/seohy/colcon_ws/src/RoboCraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_12-Sep-2026-14:20:15.791672/000/vid000.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   40 fps=0.0 q=-1.0 Lsize=    1048kB time=00:00:01.48 bitrate=5802.6kbits/s speed=4.95x
# video:1047kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.106211%
# [libx264 @ 0x617188c13a80] frame I:1     Avg QP:27.38  size: 30807
# [libx264 @ 0x617188c13a80] frame P:29    Avg QP:27.46  size: 27027
# [libx264 @ 0x617188c13a80] frame B:10    Avg QP:27.64  size: 25713
# [libx264 @ 0x617188c13a80] consecutive B-frames: 65.0%  5.0%  0.0% 30.0%
# [libx264 @ 0x617188c13a80] mb I  I16..4:  3.7% 92.7%  3.6%
# [libx264 @ 0x617188c13a80] mb P  I16..4:  0.3% 55.5%  2.8%  P16..4: 13.6% 17.0% 10.5%  0.0%  0.0%    skip: 0.2%
# [libx264 @ 0x617188c13a80] mb B  I16..4:  0.2% 42.6%  2.0%  B16..8: 33.4%  7.5%  5.5%  direct: 6.7%  skip: 2.1%  L0:47.1% L1:46.8% BI: 6.1%
# [libx264 @ 0x617188c13a80] 8x8 transform intra:94.6% inter:49.8%
# [libx264 @ 0x617188c13a80] coded y,uvDC,uvAC intra: 98.1% 22.2% 7.2% inter: 71.1% 4.0% 1.9%
# [libx264 @ 0x617188c13a80] i16 v,h,dc,p:  4% 11% 68% 16%
# [libx264 @ 0x617188c13a80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5%  5% 64%  5%  4%  4%  4%  4%  5%
# [libx264 @ 0x617188c13a80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  6% 38% 10%  8%  8%  8%  7%  7%
# [libx264 @ 0x617188c13a80] i8c dc,h,v,p: 76% 12% 12%  1%
# [libx264 @ 0x617188c13a80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x617188c13a80] ref P L0: 37.4%  9.5% 31.4% 21.7%
# [libx264 @ 0x617188c13a80] ref B L0: 66.5% 26.9%  6.5%
# [libx264 @ 0x617188c13a80] ref B L1: 84.8% 15.2%
# [libx264 @ 0x617188c13a80] kb/s:5358.58

# %%
from pathlib import Path
from IPython.display import Video, display

video_path = (Path(rollout_dir) / "000" / "vid000.mp4").resolve()

assert video_path.is_file(), f"영상 파일을 찾을 수 없어: {video_path}"
display(Video(str(video_path), embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
from pathlib import Path
from IPython.display import Image, display

frame_dir = Path(rollout_dir) / "000"
frames = sorted(frame_dir.glob("*_rgb_0.png"))

print("저장된 이미지 수:", len(frames))

if frames:
    for idx in sorted({0, len(frames) // 2, len(frames) - 1}):
        print(frames[idx].name)
        display(Image(filename=str(frames[idx])))
else:
    print("이미지를 찾을 수 없어:", frame_dir.resolve())
# Out:
# 저장된 이미지 수: 40
# 000_rgb_0.png
# 020_rgb_0.png
# 039_rgb_0.png

# %%
from pathlib import Path
from PIL import Image as PILImage
from IPython.display import Image as DisplayImage, display

frame_dir = Path(rollout_dir) / "000"
frame_paths = sorted(frame_dir.glob("*_rgb_0.png"))

frames = []
for path in frame_paths:
    with PILImage.open(path) as img:
        frames.append(img.convert("RGB"))

gif_path = frame_dir / "preview.gif"
frames[0].save(
    gif_path,
    save_all=True,
    append_images=frames[1:],
    duration=100,
    loop=0,
)

display(DisplayImage(filename=str(gif_path)))

# %%
# Out:
# GNN 체크포인트: 있음
# 초기 상태 데이터: 있음
# 목표 A 형상: 있음
# 실행 스크립트: 있음
#
# 실행 스크립트 내용:
# #!/usr/bin/env bash
#
# python control.py \
# 	--stage control \
# 	--data_type ngrip_fixed \
# 	--model_path dump/dump_ngrip_fixed/out_25-Jun-2022-14:53:02.222126/net_epoch_19_iter_34.pth \
# 	--shooting_size 200 \
# 	--control_algo predict \
# 	--n_grips 5 \
# 	--predict_horizon 2 \
# 	--opt_algo GD \
# 	--correction 1 \
# 	--shape_type alphabet \
# 	--goal_shape_name A \
# 	--debug 1
